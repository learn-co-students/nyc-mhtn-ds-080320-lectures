# %% [markdown]
# # Pandas III
#
# _August 5, 2020_
#
# Agenda today:
# - Statistics in Pandas
# - Groupby in Pandas
# - Stacking & Unstacking

# %% [markdown]
# # Part I. Statistics in Pandas
# Pandas allow us to calculate various summary statistics for the dataframe, such as mean, variance, and other descriptive statistics measurements. Let's see some examples.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# calculate mean beer_servings
df.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# calculate summary statistics for all measurements
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# how could we view summary statistics for categorical variable?
df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# reviewing subsetting and selecting - select the countries on continent AF
df[df['continent']=='AF'].head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 2        Algeria             25                0             14
# 4         Angola            217               57             45
# 18         Benin             34                4             13
# 22      Botswana            173               35             35
# 26  Burkina Faso             25                7              7
#
#     total_litres_of_pure_alcohol continent
# 2                            0.7        AF
# 4                            5.9        AF
# 18                           1.1        AF
# 22                           5.4        AF
# 26                           4.3        AF

# %%
# reviwing lambda - create a new column that indicates "low" if total_litres_of_pure_alcohol is below the mean, 
# and 'high' if above the mean
df.total_litres_of_pure_alcohol.describe()
df['high or low']=df.total_litres_of_pure_alcohol.map(lambda x:'High'if x>df.total_litres_of_pure_alcohol.mean() else 'Low' )
#df['high or low']

# %% [markdown]
# ## Part II. Pandas Groupby
# Groupby methods in Pandas allow you to aggregate data and perform operations on them. The method can be summarized as split-apply-combine. The groupby function allow us to split the dataframe into _groups_, apply operations on them, and aggregate a final result. Let's look at some examples.

# %%
# review summary statistics for each continent
df.groupby(['continent']).describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings                                             \
#              max           count        mean        std   min    25%    50%
# continent
# AF         376.0            53.0   16.339623  28.102794   0.0   1.00    3.0
# AS         247.0            44.0   60.840909  84.362160   0.0   1.00   16.0
# EU         361.0            45.0  132.555556  77.589115   0.0  81.00  122.0
# OC         306.0            16.0   58.437500  70.504817   0.0  18.00   37.0
# SA         333.0            12.0  114.750000  77.077440  25.0  65.75  108.5
#
#                          wine_servings                                    \
#               75%    max         count        mean        std  min   25%
# continent
# AF          19.00  152.0          53.0   16.264151  38.846419  0.0   1.0
# AS          98.00  326.0          44.0    9.068182  21.667034  0.0   0.0
# EU         173.00  373.0          45.0  142.222222  97.421738  0.0  59.0
# OC          65.25  254.0          16.0   35.625000  64.555790  0.0   1.0
# SA         148.75  302.0          12.0   62.416667  88.620189  1.0   3.0
#
#                                 total_litres_of_pure_alcohol            \
#              50%     75%    max                        count      mean
# continent
# AF           2.0   13.00  233.0                         53.0  3.007547
# AS           1.0    8.00  123.0                         44.0  2.170455
# EU         128.0  195.00  370.0                         45.0  8.617778
# OC           8.5   23.25  212.0                         16.0  3.381250
# SA          12.0   98.50  221.0                         12.0  6.308333
#
#
#                 std  min   25%    50%     75%   max
# continent
# AF         2.647557  0.0  0.70   2.30   4.700   9.1
# AS         2.770239  0.0  0.10   1.20   2.425  11.5
# EU         3.358455  0.0  6.60  10.00  10.900  14.4
# OC         3.345688  0.0  1.00   1.75   6.150  10.4
# SA         1.531166  3.8  5.25   6.85   7.375   8.3

# %%
# which continent drinks more beer on average?

# %%
# exercise - which continent drinks more beer than wine?

# %%
# you can also groupby multiple columns - which will result in a hierarchical index. 

# read in df from this url https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user

# and set the index as user_id
occupations= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
occupations.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
# calculate the mean age per occupation
occupations.groupby(['occupation']).age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# for each combination of sex and occupation, show the mean age, assigned it to group by age
group_by_age = occupations.groupby(['gender','occupation']).age.mean()
group_by_age
# Out:
# gender  occupation
# F       administrator    40.638889
#         artist           30.307692
#         educator         39.115385
#         engineer         29.500000
#         entertainment    31.000000
#         executive        44.000000
#         healthcare       39.818182
#         homemaker        34.166667
#         lawyer           39.500000
#         librarian        40.000000
#         marketing        37.200000
#         none             36.500000
#         other            35.472222
#         programmer       32.166667
#         retired          70.000000
#         salesman         27.000000
#         scientist        28.333333
#         student          20.750000
#         technician       38.000000
#         writer           37.631579
# M       administrator    37.162791
#         artist           32.333333
#         doctor           43.571429
#         educator         43.101449
#         engineer         36.600000
#         entertainment    29.000000
#         executive        38.172414
#         healthcare       45.400000
#         homemaker        23.000000
#         lawyer           36.200000
#         librarian        40.000000
#         marketing        37.875000
#         none             18.600000
#         other            34.028986
#         programmer       33.216667
#         retired          62.538462
#         salesman         38.555556
#         scientist        36.321429
#         student          22.669118
#         technician       32.961538
#         writer           35.346154
# Name: age, dtype: float64

# %%
# exercise - for each occupation, calculate the percentage of female and sort it from high to low
#occupations.groupby(['gender','occupation']).age.count()
occ_to_stack_or_unstack=occupations.groupby(['occupation']).gender.value_counts(normalize=True)
#percentage.items
occupations.groupby(['occupation']).gender.value_counts(normalize = True)[:,'F'].sort_values(ascending=False)
# Out:
# occupation
# homemaker        0.857143
# healthcare       0.687500
# librarian        0.568627
# artist           0.464286
# administrator    0.455696
# none             0.444444
# writer           0.422222
# marketing        0.384615
# other            0.342857
# student          0.306122
# educator         0.273684
# salesman         0.250000
# lawyer           0.166667
# entertainment    0.111111
# scientist        0.096774
# executive        0.093750
# programmer       0.090909
# retired          0.071429
# technician       0.037037
# engineer         0.029851
# Name: gender, dtype: float64

# %%
occ_to_stack_or_unstack.unstack('occupation')
# Out:
# occupation  administrator    artist  doctor  educator  engineer  \
# gender
# F                0.455696  0.464286     NaN  0.273684  0.029851
# M                0.544304  0.535714     1.0  0.726316  0.970149
#
# occupation  entertainment  executive  healthcare  homemaker    lawyer  \
# gender
# F                0.111111    0.09375      0.6875   0.857143  0.166667
# M                0.888889    0.90625      0.3125   0.142857  0.833333
#
# occupation  librarian  marketing      none     other  programmer   retired  \
# gender
# F            0.568627   0.384615  0.444444  0.342857    0.090909  0.071429
# M            0.431373   0.615385  0.555556  0.657143    0.909091  0.928571
#
# occupation  salesman  scientist   student  technician    writer
# gender
# F               0.25   0.096774  0.306122    0.037037  0.422222
# M               0.75   0.903226  0.693878    0.962963  0.577778

# %%
occupations.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-051c1bc94845> in <module>
# ----> 1 occupations.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# ## Part III. Stacking & Unstack
# Stack and unstack in Pandas provide a way for us to easily manipulate the format of our dataframes. As we see above, the row index can have hierarchy - where one level of index is nested under another. This structure can happen for columns as well. If we want to manipulate the structure of rows and columns, we need to learn stack() and unstack().
#
# **Stack()**
#
# <img src = 'stack.png' width = 450>
#
# **Unstack()**
#
# <img src = 'unstack.png' width = 450>
#
# What you you think is happening here?

# %%
# turn group by age from long to wide 
occupations.groupby('age')

# %%
# play around with stacking and unstacking for the above datasets

# %% [markdown]
# #### Optional exercises & level up - the Adult dataset

# %%
# read in the adults dataset 
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
adults = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital_status','occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss','hours_per_week', 'native_country', 'Income']
adults.columns = columns
adults.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
# create a column called income binary, 1 if income >50k 0 otherwise
adults['income_binary']=adults['Income'].map(lambda x: 1 if x== '>50K' else 0)
adults.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  Income  \
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K
#
#    income_binary
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
# explore the racial distribution of income (you should use stack or unstack here)

# this show allows us to calculate the proportion of people who earned more than 50k by race
proportion=adults.groupby(['race']).Income.value_counts(normalize=True)
proportion.unstack('Income')
# Out:
# Income                  <=50K      >50K
# race
#  Amer-Indian-Eskimo  0.884244  0.115756
#  Asian-Pac-Islander  0.734360  0.265640
#  Black               0.876120  0.123880
#  Other               0.907749  0.092251
#  White               0.744131  0.255869

# %%
# explore the gender distribution of income (you should use stack or unstack here)

# this show allows us to calculate the proportion of people who earned more than 50k by gender
proportion2=adults.groupby(['sex']).Income.value_counts(normalize=True)
proportion2.unstack('Income')
# Out:
# Income      <=50K      >50K
# sex
#  Female  0.890539  0.109461
#  Male    0.694249  0.305751

# %%
# strip the white space of the strings in the df
adults = adults.applymap(lambda x: x.strip() if type(x)==str else x)

# %%
adults
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       50  Self-emp-not-inc   83311   Bachelors             13
# 1       38           Private  215646     HS-grad              9
# 2       53           Private  234721        11th              7
# 3       28           Private  338409   Bachelors             13
# 4       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32555   27           Private  257302  Assoc-acdm             12
# 32556   40           Private  154374     HS-grad              9
# 32557   58           Private  151910     HS-grad              9
# 32558   22           Private  201490     HS-grad              9
# 32559   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4      Married-civ-spouse    Exec-managerial           Wife  White  Female
# ...                   ...                ...            ...    ...     ...
# 32555  Married-civ-spouse       Tech-support           Wife  White  Female
# 32556  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32557             Widowed       Adm-clerical      Unmarried  White  Female
# 32558       Never-married       Adm-clerical      Own-child  White    Male
# 32559  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country Income  \
# 0                 0             0              13  United-States  <=50K
# 1                 0             0              40  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40           Cuba  <=50K
# 4                 0             0              40  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 32555             0             0              38  United-States  <=50K
# 32556             0             0              40  United-States   >50K
# 32557             0             0              40  United-States  <=50K
# 32558             0             0              20  United-States  <=50K
# 32559         15024             0              40  United-States   >50K
#
#        income_binary
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 32555              0
# 32556              0
# 32557              0
# 32558              0
# 32559              0
#
# [32560 rows x 16 columns]
